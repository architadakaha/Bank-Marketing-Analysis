# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df=pd.read_csv("../DataSets/Bank.csv")

# %%
df
# Out:
#        age          job  marital            education  default housing loan  \
# 0       44  blue-collar  married             basic.4y  unknown     yes   no
# 1       53   technician  married              unknown       no      no   no
# 2       28   management   single    university.degree       no     yes   no
# 3       39     services  married          high.school       no      no   no
# 4       55      retired  married             basic.4y       no     yes   no
# ...    ...          ...      ...                  ...      ...     ...  ...
# 41183   59      retired  married          high.school  unknown      no  yes
# 41184   31    housemaid  married             basic.4y  unknown      no   no
# 41185   42       admin.   single    university.degree  unknown     yes  yes
# 41186   48   technician  married  professional.course       no      no  yes
# 41187   25      student   single          high.school       no      no   no
#
# ...

# %%
df.isnull().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp_var_rate      0
# cons_price_idx    0
# cons_conf_idx     0
# euribor3m         0
# nr_employed       0
# y                 0
# dtype: int64

# %%
df.dtypes
# Out:
# age                 int64
# job                object
# marital            object
# education          object
# default            object
# housing            object
# loan               object
# contact            object
# month              object
# day_of_week        object
# duration            int64
# campaign            int64
# pdays               int64
# previous            int64
# poutcome           object
# emp_var_rate      float64
# cons_price_idx    float64
# cons_conf_idx     float64
# euribor3m         float64
# nr_employed       float64
# y                   int64
# dtype: object

# %%
df.describe()
# Out:
#                age      duration      campaign         pdays      previous  \
# count  41188.00000  41188.000000  41188.000000  41188.000000  41188.000000
# mean      40.02406    258.285010      2.567593    962.475454      0.172963
# std       10.42125    259.279249      2.770014    186.910907      0.494901
# min       17.00000      0.000000      1.000000      0.000000      0.000000
# 25%       32.00000    102.000000      1.000000    999.000000      0.000000
# 50%       38.00000    180.000000      2.000000    999.000000      0.000000
# 75%       47.00000    319.000000      3.000000    999.000000      0.000000
# max       98.00000   4918.000000     56.000000    999.000000      7.000000
#
#        emp_var_rate  cons_price_idx  cons_conf_idx     euribor3m  \
# count  41188.000000    41188.000000   41188.000000  41188.000000
# mean       0.081886       93.575664     -40.502600      3.621291
# std        1.570960        0.578840       4.628198      1.734447
# ...

# %%
df.job.value_counts()
# Out:
# job
# admin.           10422
# blue-collar       9254
# technician        6743
# services          3969
# management        2924
# retired           1720
# entrepreneur      1456
# self-employed     1421
# housemaid         1060
# unemployed        1014
# student            875
# unknown            330
# Name: count, dtype: int64

# %%
df.education.value_counts()
# Out:
# education
# university.degree      12168
# high.school             9515
# basic.9y                6045
# professional.course     5243
# basic.4y                4176
# basic.6y                2292
# unknown                 1731
# illiterate                18
# Name: count, dtype: int64

# %%
df.month.value_counts()
# Out:
# month
# may    13769
# jul     7174
# aug     6178
# jun     5318
# nov     4101
# apr     2632
# oct      718
# sep      570
# mar      546
# dec      182
# Name: count, dtype: int64

# %%
df.marital.value_counts()
# Out:
# marital
# married     24928
# single      11568
# divorced     4612
# unknown        80
# Name: count, dtype: int64

# %%
df.groupby('job')['y'].sum()
# Out:
# job
# admin.           1352
# blue-collar       638
# entrepreneur      124
# housemaid         106
# management        328
# retired           434
# self-employed     149
# services          323
# student           275
# technician        730
# unemployed        144
# unknown            37
# Name: y, dtype: int64

# %%
df.groupby('education')['y'].sum()
# Out:
# education
# basic.4y                428
# basic.6y                188
# basic.9y                473
# high.school            1031
# illiterate                4
# professional.course     595
# university.degree      1670
# unknown                 251
# Name: y, dtype: int64

# %%
df.groupby('marital')['y'].sum()
# Out:
# marital
# divorced     476
# married     2532
# single      1620
# unknown       12
# Name: y, dtype: int64

# %%
df.groupby('default')['y'].sum()
# Out:
# default
# no         4197
# unknown     443
# yes           0
# Name: y, dtype: int64

# %%
df.groupby('month')['y'].sum()
# Out:
# month
# apr    539
# aug    655
# dec     89
# jul    649
# jun    559
# mar    276
# may    886
# nov    416
# oct    315
# sep    256
# Name: y, dtype: int64

# %%
df.y.value_counts()
# Out:
# y
# 0    36548
# 1     4640
# Name: count, dtype: int64

# %%
sb.barplot(x=df.job,y=df.y)
plt.xticks(rotation=60)
plt.show()

# %%
sb.barplot(x=df.education,y=df.y)
plt.xticks(rotation=60)
plt.show()

# %%
sb.pairplot(df)
plt.show()

# %%
df.groupby('job')['y'].sum()/41188*100
# Out:
# job
# admin.           3.282509
# blue-collar      1.548995
# entrepreneur     0.301059
# housemaid        0.257357
# management       0.796348
# retired          1.053705
# self-employed    0.361756
# services         0.784209
# student          0.667670
# technician       1.772361
# unemployed       0.349616
# unknown          0.089832
# Name: y, dtype: float64

# %%
df.groupby('education')['y'].sum()/41188*100
# Out:
# education
# basic.4y               1.039138
# basic.6y               0.456444
# basic.9y               1.148393
# high.school            2.503156
# illiterate             0.009712
# professional.course    1.444596
# university.degree      4.054579
# unknown                0.609401
# Name: y, dtype: float64

# %%
df.groupby('marital')['y'].sum()/41188*100
# Out:
# marital
# divorced    1.155676
# married     6.147422
# single      3.933184
# unknown     0.029135
# Name: y, dtype: float64

# %%
sb.countplot(x=df.job,palette='hot')
plt.xticks(rotation=50)
plt.show()
# Out:
# C:\Users\Archita Dakaha\AppData\Local\Temp\ipykernel_2256\1553906652.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sb.countplot(x=df.job,palette='hot')

# %%
sb.countplot(x=df.education,palette='ocean')
plt.xticks(rotation=50)
plt.show()
# Out:
# C:\Users\Archita Dakaha\AppData\Local\Temp\ipykernel_2256\593088996.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sb.countplot(x=df.education,palette='ocean')

# %%
sb.countplot(x=df.marital,palette='spring')
plt.show()
# Out:
# C:\Users\Archita Dakaha\AppData\Local\Temp\ipykernel_2256\3256175900.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sb.countplot(x=df.marital,palette='spring')

# %%
fig=plt.figure(figsize=[22,21])

x1=fig.add_subplot(221)
sb.countplot(x=df.job,palette='ocean')
plt.xticks(rotation=50)

x2=fig.add_subplot(222)
sb.countplot(x=df.education,palette='ocean')
plt.xticks(rotation=50)

x3=fig.add_subplot(223)
sb.countplot(x=df.marital,palette='ocean')

plt.show()
# Out:
# C:\Users\Archita Dakaha\AppData\Local\Temp\ipykernel_2256\1186752192.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sb.countplot(x=df.job,palette='ocean')
# C:\Users\Archita Dakaha\AppData\Local\Temp\ipykernel_2256\1186752192.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sb.countplot(x=df.education,palette='ocean')
# C:\Users\Archita Dakaha\AppData\Local\Temp\ipykernel_2256\1186752192.py:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sb.countplot(x=df.marital,palette='ocean')

# %%
sb.boxplot(df.y)
plt.show()

# %%
sb.boxplot(df.duration)
plt.show()

# %%
plt.scatter(df.duration,df.y)
plt.show()

# %%
df.groupby('y')['duration'].mean()
# Out:
# y
# 0    220.844807
# 1    553.191164
# Name: duration, dtype: float64

# %%
df.groupby('contact')['y'].value_counts(normalize=True)
# Out:
# contact    y
# cellular   0    0.852624
#            1    0.147376
# telephone  0    0.947687
#            1    0.052313
# Name: proportion, dtype: float64

# %%
sb.barplot(x=df.contact,y=df.y)
plt.show()

# %%
df.groupby('y')['campaign'].mean()
# Out:
# y
# 0    2.633085
# 1    2.051724
# Name: campaign, dtype: float64

# %%
sb.histplot(df.campaign)
plt.show()

# %%
sb.barplot(x=df.y,y=df.campaign)
plt.show()

# %%
df.groupby('poutcome')['y'].value_counts(normalize=True)
# Out:
# poutcome     y
# failure      0    0.857714
#              1    0.142286
# nonexistent  0    0.911678
#              1    0.088322
# success      1    0.651129
#              0    0.348871
# Name: proportion, dtype: float64

# %%
sb.barplot(x=df.poutcome,y=df.y)
plt.show()

# %%
df.groupby('previous')['y'].value_counts(normalize=True)
# Out:
# previous  y
# 0         0    0.911678
#           1    0.088322
# 1         0    0.787985
#           1    0.212015
# 2         0    0.535809
#           1    0.464191
# 3         1    0.592593
#           0    0.407407
# 4         1    0.542857
#           0    0.457143
# 5         1    0.722222
#           0    0.277778
# 6         1    0.600000
#           0    0.400000
# 7         0    1.000000
# Name: proportion, dtype: float64

# %%
sb.barplot(x=df.previous,y=df.y)
plt.show()

# %%
df.groupby('month')['y'].value_counts(normalize=True)
# Out:
# month  y
# apr    0    0.795213
#        1    0.204787
# aug    0    0.893979
#        1    0.106021
# dec    0    0.510989
#        1    0.489011
# jul    0    0.909534
#        1    0.090466
# jun    0    0.894885
#        1    0.105115
# mar    1    0.505495
#        0    0.494505
# may    0    0.935653
#        1    0.064347
# nov    0    0.898561
#        1    0.101439
# oct    0    0.561281
#        1    0.438719
# sep    0    0.550877
#        1    0.449123
# Name: proportion, dtype: float64

# %%
sb.barplot(x=df.month,y=df.y)
plt.show()

# %%
sb.lineplot(x=df.month,y=df.y)
plt.show()

# %%
df.groupby('day_of_week')['y'].value_counts(normalize=True)
# Out:
# day_of_week  y
# fri          0    0.891913
#              1    0.108087
# mon          0    0.900517
#              1    0.099483
# thu          0    0.878812
#              1    0.121188
# tue          0    0.882200
#              1    0.117800
# wed          0    0.883329
#              1    0.116671
# Name: proportion, dtype: float64

# %%
sb.barplot(x=df.day_of_week,y=df.y,palette='winter')
plt.show()
# Out:
# C:\Users\Archita Dakaha\AppData\Local\Temp\ipykernel_2256\42905685.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sb.barplot(x=df.day_of_week,y=df.y,palette='winter')
